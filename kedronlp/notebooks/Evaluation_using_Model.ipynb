# %% [markdown]
# ## Evaluation using an AI Model

# %% [markdown]
# In the following approach to create question answer pairs, an AI Model, in this case Google Gemini Advanced, is given a context which is the abstract of a paper from the PubMed Dataset and instructed to create a question of a specific type (for e.g. a Yes / No question) out of that context.
#
# Using this approach, the context provided to the AI Model becomes the answer and the question generated by the independent AI Model becomes the question for out evaluation dataset. This can then be tested on our LLM Model to see how well it performs on the generated question answer pairs using metrics like BLEU, BLEURT, etc.

# %%
import pandas as pd

df = pd.read_excel("Evaluation using Model.xlsx")

df.index += 1
df.head(60)
# Out:
#                                Question Type  \
# 1                        Open Ended Question
# 2                          Yes / No question
# 3                   Multiple choice question
# 4                        Open-ended question
# 5                            Yes/No question
# 6   Multiple Choice (with two sub-questions)
# 7                        Open-ended question
# 8                            Yes/No question
# 9   Multiple Choice (with two sub-questions)
# 10                                      What
# 11                                     Which
# 12                                      When
# 13                                       Who
# 14                                       How
# 15                                      What
# 16                                     Which
# 17                                      When
# 18                                       Who
# 19                                       How
# 20                               Comparative
# 21                               Descriptive
# 22                                       Why
# 23                                       How
# 24                              Hypothetical
# 25                              Hypothetical
# 26                       Open Ended Question
# 27                         Yes / No question
# 28                  Multiple choice question
# 29                       Open-ended question
# 30                         Yes / No question
# 31                               Comparative
# 32                       Open Ended Question
# 33                         Yes / No question
# 34                  Multiple choice question
# 35                                      What
# 36                                     Which
# 37                                      When
# 38                                       Who
# 39                                       How
# 40                                      What
# 41                                     Which
# 42                                      When
# 43                                       How
# 44                              Hypothetical
# 45                              Hypothetical
# 46                       Open Ended Question
# 47                         Yes / No question
# 48                  Multiple choice question
# 49                                      What
# 50                                       Who
# 51                                       How
# 52                                       Why
# 53                                     Where
# 54                                      When
# 55                                     Which
# 56                       Open Ended Question
# 57                                       Why
# 58                       Open Ended Question
# 59                         Yes / No question
# 60                       Open Ended Question
#
#                                              Question  \
# 1   Why might there be no significant differences ...
# 2   Do nursing students who perceive nursing as mo...
# 3   Which of the following factors is most strongl...
# 4   How does the study quantitatively demonstrate ...
# 5   Do individuals with higher IQ show resilience ...
# 6   Which brain regions are primarily responsible ...
# 7   How might exposure to lead-based industries sp...
# 8   Did the nutritional supplementation and hygien...
# 9   Which of the following is the most likely reas...
# 10  What evidence does the study provide to suppor...
# 11  Which attribute (empathy, intelligence, moral ...
# 12  When might a clinical supervisor's mindset abo...
# 13  Who might benefit from better understanding th...
# 14  How did the researchers measure the clinical s...
# 15  What areas of cognition does the PCTB assess i...
# 16  Which factor in the PCTB was most strongly rel...
# 17  When might a chimpanzee's self-control abiliti...
# 18  Who, besides chimpanzees, demonstrate a link b...
# 19  How does the Hybrid Delay Task (HDT) measure s...
# 20  How do the NART-derived WAIS-IV FSIQ estimates...
# 21  Describe the pattern of correlations between N...
# 22  Why might the most anterior face patch (AM) sh...
# 23  How do researchers use population decoding to ...
# 24  If a patient with schizophrenia presents with ...
# 25  If the prevalence of "deficit schizophrenia" i...
# 26  What factors, besides personality traits and i...
# 27  Can an individual's "Mind-space" model change ...
# 28  According to the study, which of the following...
# 29  How does the revised Carter model, which inclu...
# 30  Could the apparent increase in biological comp...
# 31  Which hypothesis (critical steps or neo-catast...
# 32  Besides drug-use impulsivity and intelligence,...
# 33  Do the factors predicting heroin DD in a state...
# 34  Which of the following best summarizes the pri...
# 35  What specific technologies does the smart home...
# 36  Which solution (5G network or web server) offe...
# 37  When might a user choose to control their smar...
# 38  Who are the intended users of this smart home ...
# 39  How does the system enable control of lighting...
# 40  What is the purpose of integrating space topol...
# 41  Which component of the architecture is respons...
# 42  When would an agent rely on space topological ...
# 43  How do the curiosity-driven rewards influence ...
# 44  What emerging field of study addresses the lim...
# 45  How can the integration of information technol...
# 46  How does the study challenge previous findings...
# 47  Did the researchers find a significant locatio...
# 48  Which factor appears to be the most important ...
# 49  What were the primary goals of the Hungarian P...
# 50  Who were the primary beneficiaries of the heal...
# 51  How did the health mediators' work increase th...
# 52  Why is the use of health mediators particularl...
# 53  Where were the GP clusters implementing the Pr...
# 54  When did the evaluation of the Primary Care Mo...
# 55  Which of the health mediators' job aspects rec...
# 56  How can clinicians improve their communication...
# 57  Why is it crucial for clinicians to recognize ...
# 58  How does a leader's level of trait empathy inf...
# 59  Does the study suggest that there are potentia...
# 60  How can nurse leaders use emotional intelligen...
#
#                                                Answer
# 1   Purpose: This study was aimed at comparing the...
# 2   "Purpose: This study was aimed at comparing th...
# 3   "Purpose: This study was aimed at comparing th...
# 4   Neuroimaging evidences posit human intelligenc...
# 5   Neuroimaging evidences posit human intelligenc...
# 6   Neuroimaging evidences posit human intelligenc...
# 7   Blood lead level and its impact on haemoglobin...
# 8   Blood lead level and its impact on haemoglobin...
# 9   Blood lead level and its impact on haemoglobin...
# 10  Purpose: Current medical education models main...
# 11  Purpose: Current medical education models main...
# 12  Purpose: Current medical education models main...
# 13  Purpose: Current medical education models main...
# 14  Purpose: Current medical education models main...
# 15  For humans, there appears to be a clear link b...
# 16  For humans, there appears to be a clear link b...
# 17  For humans, there appears to be a clear link b...
# 18  For humans, there appears to be a clear link b...
# 19  For humans, there appears to be a clear link b...
# 20  Since publication in 1982, the 50-item Nationa...
# 21  Since publication in 1982, the 50-item Nationa...
# 22  Faces are a behaviorally important class of vi...
# 23  Faces are a behaviorally important class of vi...
# 24  There is some evidence that insufficient effor...
# 25  There is some evidence that insufficient effor...
# 26  Using a "theory of mind" allows us to explain ...
# 27  Using a "theory of mind" allows us to explain ...
# 28  Using a "theory of mind" allows us to explain ...
# 29  Intelligent life has emerged late in Earth's h...
# 30  Intelligent life has emerged late in Earth's h...
# 31  Intelligent life has emerged late in Earth's h...
# 32  Delay discounting (DD) refers to how rapidly a...
# 33  Delay discounting (DD) refers to how rapidly a...
# 34  Delay discounting (DD) refers to how rapidly a...
# 35  The continuous development of the society has ...
# 36  The continuous development of the society has ...
# 37  The continuous development of the society has ...
# 38  The continuous development of the society has ...
# 39  The continuous development of the society has ...
# 40  Target-driven visual navigation is essential f...
# 41  Target-driven visual navigation is essential f...
# 42  Target-driven visual navigation is essential f...
# 43  Target-driven visual navigation is essential f...
# 44  Safety ergonomics is an important branch of sa...
# 45  Safety ergonomics is an important branch of sa...
# 46  Many studies have reported attentional biases ...
# 47  Many studies have reported attentional biases ...
# 48  Many studies have reported attentional biases ...
# 49  Background: A Primary Care Model Programme was...
# 50  Background: A Primary Care Model Programme was...
# 51  Background: A Primary Care Model Programme was...
# 52  Background: A Primary Care Model Programme was...
# 53  Background: A Primary Care Model Programme was...
# 54  Background: A Primary Care Model Programme was...
# 55  Background: A Primary Care Model Programme was...
# 56  For clinicians, effective communication goes b...
# 57  For clinicians, effective communication goes b...
# 58  Although providing negative performance feedba...
# 59  Although providing negative performance feedba...
# 60  Emotionally intelligent leaders demonstrate a ...

# %%
dictionary = df.to_dict()
